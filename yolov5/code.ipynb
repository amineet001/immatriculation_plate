# %%
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from IPython.display import Image,clear_output 
import utils

clear_output()
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-117-g85f6019 Python-3.8.10 torch-1.10.1+cu113 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11009MiB)
# Setup complete ✅ (8 CPUs, 31.0 GB RAM, 63.5/228.1 GB disk)

# %%
import os
import random
from PIL import Image

# %%
# !pwd
# !python3 train.py --img 416 --batch 16 --epochs 150 --data ./data/data.yaml --weights yolov5s.pt --cache
# Out:
# /home/amine/Bureau/plaque_immatriculation/plaque_immatriculation/immatriculation_plate/yolov5
# train: weights=yolov5s.pt, cfg=, data=./data/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /home/amine/Bureau/plaque_immatriculation/plaque_immatriculation/immatriculation_plate/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-160-g867f7f0 Python-3.10.6 torch-1.13.1+cu117 CPU
#
# ...

# %%
# !python3 detect.py --weights runs/train/exp/weights/best.pt --source "../image/car/108-ZP-69.png"
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../image/car/108-ZP-69.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /home/amine/Bureau/plaque_immatriculation/plaque_immatriculation/immatriculation_plate/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-160-g867f7f0 Python-3.10.6 torch-1.13.1+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients
# image 1/1 /home/amine/Bureau/plaque_immatriculation/plaque_immatriculation/immatriculation_plate/image/car/108-ZP-69.png: 512x640 1 licence_plate, 962.7ms
# ...
